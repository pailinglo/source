# %%
from openai import OpenAI
import os

# Initialize the client
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))  # Store your key in environment variables

def get_llm_synonyms(term, max_retries=3):
    """
    Get culinary synonyms using OpenAI's latest API
    Args:
        term: The ingredient term to find synonyms for
        max_retries: Number of retry attempts if API fails
    Returns:
        List of synonyms or None if failed
    """
    prompt = f"""List 5-10 culinary synonyms or alternative names for '{term}'.
    Include technical names, regional names, and common misspellings.
    Format as a bulleted list with no additional commentary.
    Example output for 'sticky rice':
    - glutinous rice
    - sweet rice
    - waxy rice
    - mochi rice
    - khao niao (Thai)"""
    
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "You are a culinary expert assistant."},
                    {"role": "user", "content": prompt}
                ],
                temperature=0.3,  # Lower for more deterministic results
                max_tokens=150
            )
            
            # Parse the response
            content = response.choices[0].message.content
            return [line.strip("- ").strip() for line in content.split("\n") if line.strip()]
            
        except Exception as e:
            print(f"Attempt {attempt + 1} failed: {str(e)}")
            if attempt == max_retries - 1:
                return None

# Example usage
synonyms = get_llm_synonyms("sticky rice")
print(synonyms)
# Out:
# ['glutinous rice', 'sweet rice', 'waxy rice', 'mochi rice', 'khao niao (Thai)', 'sticky glutinous rice', 'pearl rice', 'sticky sweet rice', 'sticky rice pudding', 'malagkit (Filipino)']

# %%
import os
from openai import OpenAI

# Initialize client - will automatically use the environment variable
client = OpenAI()

# Verify the key is accessible
print("API key found:", os.getenv('OPENAI_API_KEY') is not None)

# Test API call
try:
    models = client.models.list()
    print("API working successfully!")
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# API key found: True
# API working successfully!

# %%
import pyodbc
from openai import OpenAI
import os
import re

# Initialize the client
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# Database connection settings
DB_CONNECTION_STRING = "DRIVER={ODBC Driver 17 for SQL Server};SERVER=(localdb)\\MSSQLLocalDB;DATABASE=GroceryDB;Trusted_Connection=yes;"

def get_distinct_ingredients():
    """Get distinct Curated values from IngredientName that aren't already processed"""
    conn = pyodbc.connect(DB_CONNECTION_STRING)
    
    cursor = conn.cursor()
    query = """
    SELECT DISTINCT i.Curated
    FROM IngredientName i
    WHERE NOT EXISTS (
        SELECT 1 FROM IngredientSynonyms s 
        WHERE s.Name = i.Curated
    )
    AND i.Curated IS NOT NULL
    """
    
    cursor.execute(query)
    results = [row[0] for row in cursor.fetchall()]
    cursor.close()
    conn.close()
    return results

def save_synonyms_to_db(ingredient, synonym_data):
    """Save the LLM synonyms to the database"""
    conn = pyodbc.connect(DB_CONNECTION_STRING)
    
    cursor = conn.cursor()
    
    for order, (original_synonym, clean_synonym) in enumerate(synonym_data, start=1):
        # Parse the synonym for region and misspellings
        is_misspelling = 1 if "misspelling" in original_synonym.lower() else 0
        
        # Extract region if present (looking for patterns like "(Japanese)")
        # Only look for region if it's not a misspelling
        region = None
        if not is_misspelling:
            region_match = re.search(r'\(([^)]+)\)', original_synonym)
            region = region_match.group(1) if region_match else None
        
        insert_query = """
        INSERT INTO IngredientSynonyms 
        (Name, Synonym, LLMReportOrder, IsMisspelling, Region, LLMText)
        VALUES (?, ?, ?, ?, ?, ?)
        """
        
        cursor.execute(insert_query, 
                      ingredient, clean_synonym.lower(), order, is_misspelling, region, original_synonym)
    
    conn.commit()
    cursor.close()
    conn.close()

def get_llm_synonyms(term, max_retries=3):
    """
    Get culinary synonyms using OpenAI's latest API
    Args:
        term: The ingredient term to find synonyms for
        max_retries: Number of retry attempts if API fails
    Returns:
        List of tuples: (original_synonym, cleaned_synonym) or None if failed
    """
    prompt = f"""List 5-10 culinary synonyms or alternative names for '{term}'.
    Include technical names, regional names, and common misspellings.
    Format as a bulleted list with no additional commentary.
    """
    # Example output for 'sticky rice':
    # - glutinous rice
    # - sweet rice
    # - waxy rice
    # - mochi rice
    # - khao niao (Thai)
                   
    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "You are a culinary expert assistant."},
                    {"role": "user", "content": prompt}
                ],
                temperature=0.3,
                max_tokens=200
            )
            
            content = response.choices[0].message.content
            synonyms = []
            
            for line in content.split("\n"):
                if line.strip():
                    original = line.strip("- ").strip()
                    clean = re.sub(r'\s*\([^)]+\)', '', original).strip()
                    synonyms.append((original, clean))
            
            return synonyms
            
        except Exception as e:
            print(f"Attempt {attempt + 1} failed: {str(e)}")
            if attempt == max_retries - 1:
                return None

def process_ingredients():
    """Main function to process all ingredients"""
    ingredients = get_distinct_ingredients()
    
    for i, ingredient in enumerate(ingredients, start=1):
        print(f"Processing {i}/{len(ingredients)}: {ingredient}")
        
        synonyms = get_llm_synonyms(ingredient)
        
        if synonyms:
            save_synonyms_to_db(ingredient, synonyms)
            print(f"Saved {len(synonyms)} synonyms for {ingredient}")
        else:
            print(f"Failed to get synonyms for {ingredient}")

if __name__ == "__main__":
    process_ingredients()
# Out:
# Processing 1/1466: 1% milk
# Saved 10 synonyms for 1% milk
# Processing 2/1466: 2% milk
# Saved 9 synonyms for 2% milk
# Processing 3/1466: ackee
# Saved 9 synonyms for ackee
# Processing 4/1466: acorn squash
# Saved 9 synonyms for acorn squash
# Processing 5/1466: active dry yeast
# Saved 9 synonyms for active dry yeast
# Processing 6/1466: adobo
# Saved 10 synonyms for adobo
# Processing 7/1466: adobo sauce
# Saved 9 synonyms for adobo sauce
# Processing 8/1466: adzuki bean
# Saved 8 synonyms for adzuki bean
# Processing 9/1466: agar
# Saved 9 synonyms for agar
# Processing 10/1466: agave
# Saved 10 synonyms for agave
# Processing 11/1466: ahi tuna steak
# Saved 10 synonyms for ahi tuna steak
# Processing 12/1466: aioli
# Saved 10 synonyms for aioli
# Processing 13/1466: aji amarillo
# Saved 9 synonyms for aji amarillo
# Processing 14/1466: albacore tuna
# Saved 9 synonyms for albacore tuna
# Processing 15/1466: alcohol
# Saved 10 synonyms for alcohol
# Processing 16/1466: ale
# Saved 10 synonyms for ale
# Processing 17/1466: aleppo pepper
# Saved 9 synonyms for aleppo pepper
# Processing 18/1466: alfalfa sprout
# Saved 9 synonyms for alfalfa sprout
# Processing 19/1466: alfredo sauce
# Saved 10 synonyms for alfredo sauce
# Processing 20/1466: all-purpose flour
# Saved 10 synonyms for all-purpose flour
# Processing 21/1466: allspice
# Saved 10 synonyms for allspice
# Processing 22/1466: almond
# Saved 10 synonyms for almond
# Processing 23/1466: almond bark
# Saved 10 synonyms for almond bark
# Processing 24/1466: almond butter
# Saved 10 synonyms for almond butter
# Processing 25/1466: almond extract
# Saved 10 synonyms for almond extract
# Processing 26/1466: almond joy bar
# Saved 10 synonyms for almond joy bar
# Processing 27/1466: almond meal
# Saved 10 synonyms for almond meal
# Processing 28/1466: almond milk
# Saved 10 synonyms for almond milk
# Processing 29/1466: almond oil
# Saved 10 synonyms for almond oil
# Processing 30/1466: aloe vera juice
# Saved 10 synonyms for aloe vera juice
# Processing 31/1466: alum
# Saved 10 synonyms for alum
# Processing 32/1466: amaranth
# Saved 10 synonyms for amaranth
# Processing 33/1466: amaranth flour
# Saved 9 synonyms for amaranth flour
# Processing 34/1466: amaretti
# Saved 9 synonyms for amaretti
# Processing 35/1466: amaretto liqueur
# Saved 10 synonyms for amaretto liqueur
# Processing 36/1466: amchoor
# Saved 10 synonyms for amchoor
# Processing 37/1466: american cheese
# Saved 10 synonyms for american cheese
# Processing 38/1466: anaheim pepper
# Saved 10 synonyms for anaheim pepper
# Processing 39/1466: anchovy paste
# Saved 10 synonyms for anchovy paste
# Processing 40/1466: andouille
# Saved 10 synonyms for andouille
# Processing 41/1466: angel food cake
# Saved 9 synonyms for angel food cake
# Processing 42/1466: angel hair pasta
# Saved 10 synonyms for angel hair pasta
# Processing 43/1466: anise
# Saved 10 synonyms for anise
# Processing 44/1466: annatto
# Saved 9 synonyms for annatto
# Processing 45/1466: apple
# Saved 10 synonyms for apple
# Processing 46/1466: apple cider
# Saved 10 synonyms for apple cider
# Processing 47/1466: apple cider vinegar
# Saved 9 synonyms for apple cider vinegar
# Processing 48/1466: apple jelly
# Saved 10 synonyms for apple jelly
# Processing 49/1466: apple juice
# Saved 10 synonyms for apple juice
# Processing 50/1466: applesauce
# Saved 10 synonyms for applesauce
# Processing 51/1466: apricot
# Saved 10 synonyms for apricot
# Processing 52/1466: apricot jam
# Saved 10 synonyms for apricot jam
# Processing 53/1466: apricot nectar
# Saved 10 synonyms for apricot nectar
# Processing 54/1466: arrowroot
# Saved 10 synonyms for arrowroot
# Processing 55/1466: artichoke
# Saved 10 synonyms for artichoke
# Processing 56/1466: artichoke heart
# Saved 10 synonyms for artichoke heart
# Processing 57/1466: arugula
# Saved 10 synonyms for arugula
# Processing 58/1466: asafoetida
# Saved 10 synonyms for asafoetida
# Processing 59/1466: asiago cheese
# Saved 10 synonyms for asiago cheese
# Processing 60/1466: asian dressing
# Saved 10 synonyms for asian dressing
# Processing 61/1466: asparagus
# Saved 9 synonyms for asparagus
# Processing 62/1466: avocado
# Saved 9 synonyms for avocado
# Processing 63/1466: avocado oil
# Saved 9 synonyms for avocado oil
# Processing 64/1466: baby artichoke
# Saved 10 synonyms for baby artichoke
# Processing 65/1466: baby arugula
# Saved 10 synonyms for baby arugula
# Processing 66/1466: baby beet
# Saved 10 synonyms for baby beet
# Processing 67/1466: baby carrot
# Saved 10 synonyms for baby carrot
# Processing 68/1466: baby corn
# Saved 10 synonyms for baby corn
# Processing 69/1466: baby leek
# Saved 10 synonyms for baby leek
# Processing 70/1466: baby lima bean
# Saved 10 synonyms for baby lima bean
# Processing 71/1466: baby rib
# Saved 10 synonyms for baby rib
# Processing 72/1466: baby spinach
# Saved 10 synonyms for baby spinach
# Processing 73/1466: baby zucchini
# Saved 10 synonyms for baby zucchini
# Processing 74/1466: bacon
# Saved 10 synonyms for bacon
# Processing 75/1466: bacon fat
# Saved 10 synonyms for bacon fat
# Processing 76/1466: bagel
# Saved 10 synonyms for bagel
# Processing 77/1466: bagel chips
# Saved 10 synonyms for bagel chips
# Processing 78/1466: bakers white chocolate
# Saved 10 synonyms for bakers white chocolate
# Processing 79/1466: baking chocolate
# Saved 10 synonyms for baking chocolate
# Processing 80/1466: baking mix
# Saved 10 synonyms for baking mix
# Processing 81/1466: baking powder
# Saved 9 synonyms for baking powder
# Processing 82/1466: baking soda
# Saved 10 synonyms for baking soda
# Processing 83/1466: balsamic glaze
# Saved 10 synonyms for balsamic glaze
# Processing 84/1466: balsamic vinaigrette
# Saved 10 synonyms for balsamic vinaigrette
# Processing 85/1466: balsamic vinegar
# Saved 10 synonyms for balsamic vinegar
# Processing 86/1466: bamboo shoot
# Saved 9 synonyms for bamboo shoot
# Processing 87/1466: banana
# Saved 10 synonyms for banana
# Processing 88/1466: banana blossom
# Saved 10 synonyms for banana blossom
# Processing 89/1466: banana leaf
# Saved 10 synonyms for banana leaf
# Processing 90/1466: banana pepper
# Saved 9 synonyms for banana pepper
# Processing 91/1466: barbecue seasoning
# Saved 10 synonyms for barbecue seasoning
# Processing 92/1466: barley
# Saved 10 synonyms for barley
# Processing 93/1466: bartlett pear
# Saved 9 synonyms for bartlett pear
# Processing 94/1466: basil oil
# Saved 10 synonyms for basil oil
# Processing 95/1466: basil pesto
# Saved 10 synonyms for basil pesto
# Processing 96/1466: bass
# Saved 10 synonyms for bass
# Processing 97/1466: bay leaf
# Saved 10 synonyms for bay leaf
# Processing 98/1466: bay scallops
# Saved 10 synonyms for bay scallops
# Processing 99/1466: bbq sauce
# Saved 10 synonyms for bbq sauce
# Processing 100/1466: bean
# Saved 10 synonyms for bean
# Processing 101/1466: bean sprout
# Saved 10 synonyms for bean sprout
# Processing 102/1466: beef
# Saved 10 synonyms for beef
# Processing 103/1466: beef base
# Saved 10 synonyms for beef base
# Processing 104/1466: beef bone
# Saved 10 synonyms for beef bone
# Processing 105/1466: beef bouillon
# Saved 10 synonyms for beef bouillon
# Processing 106/1466: beef bouillon cube
# Saved 9 synonyms for beef bouillon cube
# Processing 107/1466: beef brisket
# Saved 9 synonyms for beef brisket
# Processing 108/1466: beef broth
# Saved 10 synonyms for beef broth
# Processing 109/1466: beef chuck roast
# Saved 9 synonyms for beef chuck roast
# Processing 110/1466: beef gravy
# Saved 10 synonyms for beef gravy
# Processing 111/1466: beef ramen
# Saved 10 synonyms for beef ramen
# Processing 112/1466: beef shank
# Saved 10 synonyms for beef shank
# Processing 113/1466: beef short rib
# Saved 9 synonyms for beef short rib
# Processing 114/1466: beef stock
# Saved 10 synonyms for beef stock
# Processing 115/1466: beef tenderloin
# Saved 10 synonyms for beef tenderloin
# Processing 116/1466: beefsteak tomato
# Saved 10 synonyms for beefsteak tomato
# Processing 117/1466: beer
# Saved 10 synonyms for beer
# Processing 118/1466: beet
# Saved 10 synonyms for beet
# Processing 119/1466: beet green
# Saved 10 synonyms for beet green
# Processing 120/1466: belacan
# Saved 9 synonyms for belacan
# Processing 121/1466: bell pepper
# Saved 10 synonyms for bell pepper
# Processing 122/1466: berbere
# Saved 9 synonyms for berbere
# Processing 123/1466: berry
# Saved 10 synonyms for berry
# Processing 124/1466: bitter
# Saved 10 synonyms for bitter
# Processing 125/1466: black bean
# Saved 9 synonyms for black bean
# Processing 126/1466: black bean sauce
# Saved 9 synonyms for black bean sauce
# Processing 127/1466: black currant
# Saved 10 synonyms for black currant
# Processing 128/1466: black forest ham
# Saved 10 synonyms for black forest ham
# Processing 129/1466: black lentil
# Saved 9 synonyms for black lentil
# Processing 130/1466: black olive
# Saved 10 synonyms for black olive
# Processing 131/1466: black pepper
# Saved 9 synonyms for black pepper
# Processing 132/1466: black vinegar
# Saved 10 synonyms for black vinegar
# Processing 133/1466: blackberry
# Saved 10 synonyms for blackberry
# Processing 134/1466: blackening spice
# Saved 9 synonyms for blackening spice
# Processing 135/1466: blackeyed pea
# Saved 10 synonyms for blackeyed pea
# Processing 136/1466: block cream cheese
# Saved 9 synonyms for block cream cheese
# Processing 137/1466: blood orange
# Saved 10 synonyms for blood orange
# Processing 138/1466: blood orange juice
# Saved 9 synonyms for blood orange juice
# Processing 139/1466: blood orange zest
# Saved 9 synonyms for blood orange zest
# Processing 140/1466: blue cheese dressing
# Saved 10 synonyms for blue cheese dressing
# Processing 141/1466: blueberry
# Saved 10 synonyms for blueberry
# Processing 142/1466: bluefish fillet
# Saved 9 synonyms for bluefish fillet
# Processing 143/1466: bocconcini
# Saved 9 synonyms for bocconcini
# Processing 144/1466: boiled egg
# Saved 10 synonyms for boiled egg
# Processing 145/1466: bok choy
# Saved 10 synonyms for bok choy
# Processing 146/1466: bonito flake
# Saved 10 synonyms for bonito flake
# Processing 147/1466: boquerone
# Saved 10 synonyms for boquerone
# Processing 148/1466: borlotti bean
# Saved 9 synonyms for borlotti bean
# Processing 149/1466: bouillon
# Saved 10 synonyms for bouillon
# Processing 150/1466: bouillon cube
# Saved 10 synonyms for bouillon cube
# Processing 151/1466: bouquet garni
# Saved 10 synonyms for bouquet garni
# Processing 152/1466: bourbon
# Saved 9 synonyms for bourbon
# Processing 153/1466: boursin cheese
# Saved 9 synonyms for boursin cheese
# Processing 154/1466: bramley apple
# Saved 10 synonyms for bramley apple
# Processing 155/1466: bran cereal
# Saved 9 synonyms for bran cereal
# Processing 156/1466: bran flake
# Saved 10 synonyms for bran flake
# Processing 157/1466: brandy
# Saved 10 synonyms for brandy
# Processing 158/1466: bratwurst
# Saved 10 synonyms for bratwurst
# Processing 159/1466: brazil nuts
# Saved 10 synonyms for brazil nuts
# Processing 160/1466: bread
# Saved 10 synonyms for bread
# Processing 161/1466: bread bowl
# Saved 10 synonyms for bread bowl
# Processing 162/1466: bread dough
# Saved 10 synonyms for bread dough
# Processing 163/1466: bread flour
# Saved 10 synonyms for bread flour
# Processing 164/1466: breadcrumb
# Saved 10 synonyms for breadcrumb
# Processing 165/1466: brie
# Saved 8 synonyms for brie
# Processing 166/1466: brine
# Saved 10 synonyms for brine
# Processing 167/1466: brioche
# Saved 9 synonyms for brioche
# Processing 168/1466: broccoli
# Saved 10 synonyms for broccoli
# Processing 169/1466: broccoli rabe
# Saved 10 synonyms for broccoli rabe
# Processing 170/1466: broccoli slaw
# Saved 9 synonyms for broccoli slaw
# Processing 171/1466: broccoli sprout
# Saved 10 synonyms for broccoli sprout
# Processing 172/1466: broccolini
# Saved 8 synonyms for broccolini
# Processing 173/1466: brown rice
# Saved 10 synonyms for brown rice
# Processing 174/1466: brown rice pasta
# Saved 10 synonyms for brown rice pasta
# Processing 175/1466: brown sugar
# Saved 10 synonyms for brown sugar
# Processing 176/1466: brownie mix
# Saved 10 synonyms for brownie mix
# Processing 177/1466: brussels sprouts
# Saved 9 synonyms for brussels sprouts
# Processing 178/1466: bucatini
# Saved 9 synonyms for bucatini
# Processing 179/1466: buckweat flour
# Saved 9 synonyms for buckweat flour
# Processing 180/1466: buckwheat
# Saved 8 synonyms for buckwheat
# Processing 181/1466: buffalo mozzarella
# Saved 9 synonyms for buffalo mozzarella
# Processing 182/1466: buffalo sauce
# Saved 10 synonyms for buffalo sauce
# Processing 183/1466: bulgur
# Saved 10 synonyms for bulgur
# Processing 184/1466: bun
# Saved 10 synonyms for bun
# Processing 185/1466: burger
# Saved 10 synonyms for burger
# Processing 186/1466: burger bun
# Saved 10 synonyms for burger bun
# Processing 187/1466: burrata
# Saved 10 synonyms for burrata
# Processing 188/1466: butter bean
# Saved 10 synonyms for butter bean
# Processing 189/1466: butter lettuce
# Saved 10 synonyms for butter lettuce
# Processing 190/1466: buttermilk
# Saved 10 synonyms for buttermilk
# Processing 191/1466: buttermilk biscuit
# Saved 10 synonyms for buttermilk biscuit
# Processing 192/1466: butternut squash
# Saved 10 synonyms for butternut squash
# Processing 193/1466: butterscotch
# Saved 10 synonyms for butterscotch
# Processing 194/1466: cabbage
# Saved 10 synonyms for cabbage
# Processing 195/1466: cabernet sauvignon
# Saved 10 synonyms for cabernet sauvignon
# Processing 196/1466: cacao powder
# Saved 10 synonyms for cacao powder
# Processing 197/1466: cachaca
# Saved 10 synonyms for cachaca
# Processing 198/1466: caesar salad dressing
# Saved 10 synonyms for caesar salad dressing
# Processing 199/1466: cajun seasoning
# Saved 9 synonyms for cajun seasoning
# Processing 200/1466: cake mix
# Saved 10 synonyms for cake mix
# Processing 201/1466: calvados
# Saved 10 synonyms for calvados
# Processing 202/1466: camembert
# Saved 11 synonyms for camembert
# Processing 203/1466: campari
# Saved 10 synonyms for campari
# Processing 204/1466: canadian bacon
# Saved 9 synonyms for canadian bacon
# Processing 205/1466: candied ginger
# Saved 10 synonyms for candied ginger
# Processing 206/1466: candied pecan
# Saved 10 synonyms for candied pecan
# Processing 207/1466: candy cane
# Saved 10 synonyms for candy cane
# Processing 208/1466: canned anchovy
# Saved 10 synonyms for canned anchovy
# Processing 209/1466: canned beet
# Saved 10 synonyms for canned beet
# Processing 210/1466: canned black beans
# Saved 10 synonyms for canned black beans
# Processing 211/1466: canned chicken
# Saved 10 synonyms for canned chicken
# Processing 212/1466: canned chicken breast
# Saved 10 synonyms for canned chicken breast
# Processing 213/1466: canned chickpea
# Saved 10 synonyms for canned chickpea
# Processing 214/1466: canned chipotle chile
# Saved 10 synonyms for canned chipotle chile
# Processing 215/1466: canned cranberry bean
# Saved 9 synonyms for canned cranberry bean
# Processing 216/1466: canned diced tomato
# Saved 10 synonyms for canned diced tomato
# Processing 217/1466: canned kidney bean
# Saved 9 synonyms for canned kidney bean
# Processing 218/1466: canned navy bean
# Saved 9 synonyms for canned navy bean
# Processing 219/1466: canned pinto bean
# Saved 10 synonyms for canned pinto bean
# Processing 220/1466: canned salmon
# Saved 10 synonyms for canned salmon
# Processing 221/1466: canned tomato
# Saved 10 synonyms for canned tomato
# Processing 222/1466: canned tuna
# Saved 10 synonyms for canned tuna
# Processing 223/1466: canned water chestnut
# Saved 10 synonyms for canned water chestnut
# Processing 224/1466: canned white bean
# Saved 9 synonyms for canned white bean
# Processing 225/1466: cannellini bean
# Saved 9 synonyms for cannellini bean
# Processing 226/1466: canola oil
# Saved 10 synonyms for canola oil
# Processing 227/1466: cantaloupe
# Saved 9 synonyms for cantaloupe
# Processing 228/1466: capellini
# Saved 10 synonyms for capellini
# Processing 229/1466: caper
# Saved 10 synonyms for caper
# Processing 230/1466: caper berry
# Saved 10 synonyms for caper berry
# Processing 231/1466: capicola
# Saved 10 synonyms for capicola
# Processing 232/1466: caramel popcorn
# Saved 10 synonyms for caramel popcorn
# Processing 233/1466: caramel sauce
# Saved 10 synonyms for caramel sauce
# Processing 234/1466: caraway seed
# Saved 10 synonyms for caraway seed
# Processing 235/1466: cardamom
# Saved 10 synonyms for cardamom
# Processing 236/1466: cardamom powder
# Saved 9 synonyms for cardamom powder
# Processing 237/1466: carp
# Saved 10 synonyms for carp
# Processing 238/1466: Carrageenan
# Saved 10 synonyms for Carrageenan
# Processing 239/1466: carrot
# Saved 10 synonyms for carrot
# Processing 240/1466: carrot greens
# Saved 10 synonyms for carrot greens
# Processing 241/1466: carrot juice
# Saved 10 synonyms for carrot juice
# Processing 242/1466: cashew
# Saved 9 synonyms for cashew
# Processing 243/1466: cashew milk
# Saved 9 synonyms for cashew milk
# Processing 244/1466: cassava
# Saved 10 synonyms for cassava
# Processing 245/1466: catalina dressing
# Saved 9 synonyms for catalina dressing
# Processing 246/1466: catfish
# Saved 9 synonyms for catfish
# Processing 247/1466: catfish fillet
# Saved 10 synonyms for catfish fillet
# Processing 248/1466: cauliflower
# Saved 9 synonyms for cauliflower
# Processing 249/1466: cavatappi
# Saved 10 synonyms for cavatappi
# Processing 250/1466: cavatelli
# Saved 10 synonyms for cavatelli
# Processing 251/1466: caviar
# Saved 10 synonyms for caviar
# Processing 252/1466: cayenne
# Saved 10 synonyms for cayenne
# Processing 253/1466: cedar plank
# Saved 10 synonyms for cedar plank
# Processing 254/1466: celeriac
# Saved 10 synonyms for celeriac
# Processing 255/1466: celery
# Saved 10 synonyms for celery
# Processing 256/1466: celery leaf
# Saved 10 synonyms for celery leaf
# Processing 257/1466: celery salt
# Saved 10 synonyms for celery salt
# Processing 258/1466: celery seed
# Saved 9 synonyms for celery seed
# Processing 259/1466: cellophane noodle
# Saved 9 synonyms for cellophane noodle
# Processing 260/1466: challah
# Saved 10 synonyms for challah
# Processing 261/1466: champagne
# Saved 10 synonyms for champagne
# Processing 262/1466: champagne vinegar
# Saved 10 synonyms for champagne vinegar
# Processing 263/1466: chanterelle mushroom
# Saved 10 synonyms for chanterelle mushroom
# Processing 264/1466: chardonnay
# Saved 9 synonyms for chardonnay
# Processing 265/1466: cheddar
# Saved 9 synonyms for cheddar
# Processing 266/1466: cheddar cheese
# Saved 9 synonyms for cheddar cheese
# Processing 267/1466: cheddar cheese soup
# Saved 10 synonyms for cheddar cheese soup
# Processing 268/1466: cheese
# Saved 10 synonyms for cheese
# Processing 269/1466: cheese ravioli
# Saved 9 synonyms for cheese ravioli
# Processing 270/1466: cheese tortellini
# Saved 10 synonyms for cheese tortellini
# Processing 271/1466: cheez whiz
# Saved 9 synonyms for cheez whiz
# Processing 272/1466: cherry
# Saved 10 synonyms for cherry
# Processing 273/1466: cherry jam
# Saved 10 synonyms for cherry jam
# Processing 274/1466: cherry juice
# Saved 10 synonyms for cherry juice
# Processing 275/1466: cherry tomato
# Saved 9 synonyms for cherry tomato
# Processing 276/1466: chervil
# Saved 9 synonyms for chervil
# Processing 277/1466: chestnut
# Saved 10 synonyms for chestnut
# Processing 278/1466: chestnut flour
# Saved 10 synonyms for chestnut flour
# Processing 279/1466: chex mix
# Saved 10 synonyms for chex mix
# Processing 280/1466: chia seeds
# Saved 9 synonyms for chia seeds
# Processing 281/1466: chianti
# Saved 10 synonyms for chianti
# Processing 282/1466: chicken
# Saved 10 synonyms for chicken
# Processing 283/1466: chicken base
# Saved 10 synonyms for chicken base
# Processing 284/1466: chicken bone
# Saved 10 synonyms for chicken bone
# Processing 285/1466: chicken bouillon
# Saved 10 synonyms for chicken bouillon
# Processing 286/1466: chicken breast
# Saved 10 synonyms for chicken breast
# Processing 287/1466: chicken broth
# Saved 10 synonyms for chicken broth
# Processing 288/1466: chicken cutlet
# Saved 10 synonyms for chicken cutlet
# Processing 289/1466: chicken drumstick
# Saved 10 synonyms for chicken drumstick
# Processing 290/1466: chicken fat
# Saved 10 synonyms for chicken fat
# Processing 291/1466: chicken foot
# Saved 10 synonyms for chicken foot
# Processing 292/1466: chicken gravy
# Saved 10 synonyms for chicken gravy
# Processing 293/1466: chicken leg
# Saved 10 synonyms for chicken leg
# Processing 294/1466: chicken liver
# Saved 9 synonyms for chicken liver
# Processing 295/1466: chicken sausage
# Saved 10 synonyms for chicken sausage
# Processing 296/1466: chicken seasoning
# Saved 10 synonyms for chicken seasoning
# Processing 297/1466: chicken stock
# Saved 10 synonyms for chicken stock
# Processing 298/1466: chicken tender
# Saved 10 synonyms for chicken tender
# Processing 299/1466: chicken thigh
# Saved 10 synonyms for chicken thigh
# Processing 300/1466: chicken wing
# Saved 10 synonyms for chicken wing
# Processing 301/1466: chickpea
# Saved 9 synonyms for chickpea
# Processing 302/1466: chickpea flour
# Saved 10 synonyms for chickpea flour
# Processing 303/1466: chilean seabass
# Saved 9 synonyms for chilean seabass
# Processing 304/1466: chili
# Saved 10 synonyms for chili
# Processing 305/1466: chili garlic sauce
# Saved 10 synonyms for chili garlic sauce
# Processing 306/1466: chili oil
# Saved 10 synonyms for chili oil
# Processing 307/1466: chili paste
# Saved 9 synonyms for chili paste
# Processing 308/1466: chili pepper
# Saved 10 synonyms for chili pepper
# Processing 309/1466: chili powder
# Saved 10 synonyms for chili powder
# Processing 310/1466: chili sauce
# Saved 10 synonyms for chili sauce
# Processing 311/1466: chinese five spice
# Saved 9 synonyms for chinese five spice
# Processing 312/1466: chipotle
# Saved 10 synonyms for chipotle
# Processing 313/1466: chipotle chile
# Saved 10 synonyms for chipotle chile
# Processing 314/1466: chipotle chile pepper
# Saved 9 synonyms for chipotle chile pepper
# Processing 315/1466: chive and onion cream cheese spread
# Saved 9 synonyms for chive and onion cream cheese spread
# Processing 316/1466: chives
# Saved 10 synonyms for chives
# Processing 317/1466: chocolate
# Saved 10 synonyms for chocolate
# Processing 318/1466: chocolate chip
# Saved 10 synonyms for chocolate chip
# Processing 319/1466: chocolate chip cookie
# Saved 9 synonyms for chocolate chip cookie
# Processing 320/1466: chocolate egg
# Saved 10 synonyms for chocolate egg
# Processing 321/1466: chocolate mint
# Saved 10 synonyms for chocolate mint
# Processing 322/1466: chocolate spread
# Saved 10 synonyms for chocolate spread
# Processing 323/1466: chorizo
# Saved 9 synonyms for chorizo
# Processing 324/1466: chow mein noodle
# Saved 10 synonyms for chow mein noodle
# Processing 325/1466: choy sum
# Saved 9 synonyms for choy sum
# Processing 326/1466: ciabatta
# Saved 10 synonyms for ciabatta
# Processing 327/1466: ciabatta roll
# Saved 10 synonyms for ciabatta roll
# Processing 328/1466: cilantro
# Saved 9 synonyms for cilantro
# Processing 329/1466: cinnamon
# Saved 10 synonyms for cinnamon
# Processing 330/1466: cinnamon stick
# Saved 10 synonyms for cinnamon stick
# Processing 331/1466: cipollini onion
# Saved 9 synonyms for cipollini onion
# Processing 332/1466: citric acid
# Saved 10 synonyms for citric acid
# Processing 333/1466: clam
# Saved 10 synonyms for clam
# Processing 334/1466: clam juice
# Saved 10 synonyms for clam juice
# Processing 335/1466: clarified butter
# Saved 10 synonyms for clarified butter
# Processing 336/1466: clementine
# Saved 10 synonyms for clementine
# Processing 337/1466: clove
# Saved 10 synonyms for clove
# Processing 338/1466: cockle
# Saved 10 synonyms for cockle
# Processing 339/1466: cocoa nib
# Saved 10 synonyms for cocoa nib
# Processing 340/1466: cocoa powder
# Saved 10 synonyms for cocoa powder
# Processing 341/1466: coconut
# Saved 10 synonyms for coconut
# Processing 342/1466: coconut aminos
# Saved 10 synonyms for coconut aminos
# Processing 343/1466: coconut cream
# Saved 10 synonyms for coconut cream
# Processing 344/1466: coconut creamer
# Saved 10 synonyms for coconut creamer
# Processing 345/1466: coconut flake
# Saved 10 synonyms for coconut flake
# Processing 346/1466: coconut flour
# Saved 9 synonyms for coconut flour
# Processing 347/1466: coconut milk
# Saved 10 synonyms for coconut milk
# Processing 348/1466: coconut oil
# Saved 10 synonyms for coconut oil
# Processing 349/1466: coconut sugar
# Saved 10 synonyms for coconut sugar
# Processing 350/1466: coconut vinegar
# Saved 9 synonyms for coconut vinegar
# Processing 351/1466: coconut water
# Saved 10 synonyms for coconut water
# Processing 352/1466: cod fillet
# Saved 10 synonyms for cod fillet
# Processing 353/1466: coffee
# Saved 10 synonyms for coffee
# Processing 354/1466: coffee liqueur
# Saved 10 synonyms for coffee liqueur
# Processing 355/1466: cognac
# Saved 9 synonyms for cognac
# Processing 356/1466: cola
# Saved 10 synonyms for cola
# Processing 357/1466: colby jack cheese
# Saved 10 synonyms for colby jack cheese
# Processing 358/1466: coleslaw dressing
# Saved 10 synonyms for coleslaw dressing
# Processing 359/1466: coleslaw mix
# Saved 10 synonyms for coleslaw mix
# Processing 360/1466: collard green
# Saved 10 synonyms for collard green
# Processing 361/1466: comte
# Saved 10 synonyms for comte
# Processing 362/1466: cooked spelt
# Saved 10 synonyms for cooked spelt
# Processing 363/1466: cookie
# Saved 10 synonyms for cookie
# Processing 364/1466: cooking fat
# Saved 10 synonyms for cooking fat
# Processing 365/1466: cooking oil
# Saved 10 synonyms for cooking oil
# Processing 366/1466: coriander
# Saved 9 synonyms for coriander
# Processing 367/1466: coriander seed
# Saved 10 synonyms for coriander seed
# Processing 368/1466: corkscrew pasta
# Saved 10 synonyms for corkscrew pasta
# Processing 369/1466: corn
# Saved 10 synonyms for corn
# Processing 370/1466: corn cereal
# Saved 10 synonyms for corn cereal
# Processing 371/1466: corn chip
# Saved 10 synonyms for corn chip
# Processing 372/1466: corn flake crumb
# Saved 10 synonyms for corn flake crumb
# Processing 373/1466: corn flour
# Saved 9 synonyms for corn flour
# Processing 374/1466: corn husk
# Saved 10 synonyms for corn husk
# Processing 375/1466: corn oil
# Saved 9 synonyms for corn oil
# Processing 376/1466: corn starch
# Saved 10 synonyms for corn starch
# Processing 377/1466: corn syrup
# Saved 9 synonyms for corn syrup
# Processing 378/1466: corn tortilla
# Saved 10 synonyms for corn tortilla
# Processing 379/1466: corn tortilla chip
# Saved 10 synonyms for corn tortilla chip
# Processing 380/1466: cornbread
# Saved 10 synonyms for cornbread
# Processing 381/1466: cornbread mix
# Saved 10 synonyms for cornbread mix
# Processing 382/1466: corned beef
# Saved 9 synonyms for corned beef
# Processing 383/1466: cornish hen
# Saved 10 synonyms for cornish hen
# Processing 384/1466: cornmeal
# Saved 10 synonyms for cornmeal
# Processing 385/1466: cornmeal mix
# Saved 10 synonyms for cornmeal mix
# Processing 386/1466: cotija cheese
# Saved 10 synonyms for cotija cheese
# Processing 387/1466: cottage cheese
# Saved 10 synonyms for cottage cheese
# Processing 388/1466: couscous
# Saved 9 synonyms for couscous
# Processing 389/1466: crab
# Saved 10 synonyms for crab
# Processing 390/1466: crab seasoning
# Saved 10 synonyms for crab seasoning
# Processing 391/1466: crabmeat
# Saved 10 synonyms for crabmeat
# Processing 392/1466: cracked wheat
# Saved 10 synonyms for cracked wheat
# Processing 393/1466: cracker
# Saved 10 synonyms for cracker
# Processing 394/1466: cracker crumb
# Saved 10 synonyms for cracker crumb
# Processing 395/1466: cranberry
# Saved 10 synonyms for cranberry
# Processing 396/1466: cranberry bean
# Saved 9 synonyms for cranberry bean
# Processing 397/1466: cranberry juice
# Saved 9 synonyms for cranberry juice
# Processing 398/1466: cranberry juice concentrate
# Saved 10 synonyms for cranberry juice concentrate
# Processing 399/1466: cranberry sauce
# Saved 10 synonyms for cranberry sauce
# Processing 400/1466: crawfish
# Saved 10 synonyms for crawfish
# Processing 401/1466: cream
# Saved 10 synonyms for cream
# Processing 402/1466: cream cheese
# Saved 10 synonyms for cream cheese
# Processing 403/1466: cream of celery soup
# Saved 10 synonyms for cream of celery soup
# Processing 404/1466: cream of chicken soup
# Saved 10 synonyms for cream of chicken soup
# Processing 405/1466: cream of mushroom soup
# Saved 10 synonyms for cream of mushroom soup
# Processing 406/1466: cream of tartar
# Saved 9 synonyms for cream of tartar
# Processing 407/1466: cream soda
# Saved 10 synonyms for cream soda
# Processing 408/1466: creamed corn
# Saved 10 synonyms for creamed corn
# Processing 409/1466: creme de cacao
# Saved 9 synonyms for creme de cacao
# Processing 410/1466: creme fraiche
# Saved 10 synonyms for creme fraiche
# Processing 411/1466: creole mustard
# Saved 10 synonyms for creole mustard
# Processing 412/1466: creole seasoning
# Saved 9 synonyms for creole seasoning
# Processing 413/1466: crepes
# Saved 9 synonyms for crepes
# Processing 414/1466: crescent roll
# Saved 10 synonyms for crescent roll
# Processing 415/1466: crimini mushroom
# Saved 9 synonyms for crimini mushroom
# Processing 416/1466: croissant
# Saved 10 synonyms for croissant
# Processing 417/1466: crostini
# Saved 10 synonyms for crostini
# Processing 418/1466: crouton
# Saved 10 synonyms for crouton
# Processing 419/1466: cubanelle pepper
# Saved 9 synonyms for cubanelle pepper
# Processing 420/1466: cube steak
# Saved 10 synonyms for cube steak
# Processing 421/1466: cucumber
# Saved 10 synonyms for cucumber
# Processing 422/1466: cumin
# Saved 9 synonyms for cumin
# Processing 423/1466: cumin seed
# Saved 10 synonyms for cumin seed
# Processing 424/1466: cupcake
# Saved 10 synonyms for cupcake
# Processing 425/1466: curly endive
# Saved 10 synonyms for curly endive
# Processing 426/1466: curly lettuce
# Saved 10 synonyms for curly lettuce
# Processing 427/1466: curry leaf
# Saved 10 synonyms for curry leaf
# Processing 428/1466: curry paste
# Saved 10 synonyms for curry paste
# Processing 429/1466: curry powder
# Saved 10 synonyms for curry powder
# Processing 430/1466: cuttlefish
# Saved 9 synonyms for cuttlefish
# Processing 431/1466: daikon
# Saved 10 synonyms for daikon
# Processing 432/1466: daikon sprout
# Saved 10 synonyms for daikon sprout
# Processing 433/1466: dandelion green
# Saved 10 synonyms for dandelion green
# Processing 434/1466: dashi
# Saved 10 synonyms for dashi
# Processing 435/1466: date
# Saved 10 synonyms for date
# Processing 436/1466: deli turkey
# Saved 10 synonyms for deli turkey
# Processing 437/1466: delicata squash
# Saved 10 synonyms for delicata squash
# Processing 438/1466: demerara sugar
# Saved 9 synonyms for demerara sugar
# Processing 439/1466: demi glace
# Saved 9 synonyms for demi glace
# Processing 440/1466: diced ham
# Saved 10 synonyms for diced ham
# Processing 441/1466: diet soda
# Saved 10 synonyms for diet soda
# Processing 442/1466: dijon mustard
# Saved 10 synonyms for dijon mustard
# Processing 443/1466: dill
# Saved 10 synonyms for dill
# Processing 444/1466: dill pickle
# Saved 10 synonyms for dill pickle
# Processing 445/1466: dill seed
# Saved 10 synonyms for dill seed
# Processing 446/1466: dinner roll
# Saved 10 synonyms for dinner roll
# Processing 447/1466: ditalini
# Saved 10 synonyms for ditalini
# Processing 448/1466: double cream
# Saved 10 synonyms for double cream
# Processing 449/1466: douchi
# Saved 10 synonyms for douchi
# Processing 450/1466: dough
# Saved 10 synonyms for dough
# Processing 451/1466: dr pepper
# Saved 10 synonyms for dr pepper
# Processing 452/1466: dried adzuki bean
# Saved 10 synonyms for dried adzuki bean
# Processing 453/1466: dried apricot
# Saved 9 synonyms for dried apricot
# Processing 454/1466: dried arbol chile
# Saved 9 synonyms for dried arbol chile
# Processing 455/1466: dried basil
# Saved 10 synonyms for dried basil
# Processing 456/1466: dried blueberry
# Saved 9 synonyms for dried blueberry
# Processing 457/1466: dried cherry
# Saved 10 synonyms for dried cherry
# Processing 458/1466: dried coriander
# Saved 9 synonyms for dried coriander
# Processing 459/1466: dried cranberry
# Saved 10 synonyms for dried cranberry
# Processing 460/1466: dried cranberry bean
# Saved 9 synonyms for dried cranberry bean
# Processing 461/1466: dried currant
# Saved 10 synonyms for dried currant
# Processing 462/1466: dried fig
# Saved 9 synonyms for dried fig
# Processing 463/1466: dried fruit
# Saved 10 synonyms for dried fruit
# Processing 464/1466: dried herb
# Saved 10 synonyms for dried herb
# Processing 465/1466: dried sage
# Saved 10 synonyms for dried sage
# Processing 466/1466: dried thyme
# Saved 9 synonyms for dried thyme
# Processing 467/1466: dry cider
# Saved 10 synonyms for dry cider
# Processing 468/1466: dry milk
# Saved 10 synonyms for dry milk
# Processing 469/1466: dry sherry
# Saved 10 synonyms for dry sherry
# Processing 470/1466: duck
# Saved 10 synonyms for duck
# Processing 471/1466: duck breast
# Saved 10 synonyms for duck breast
# Processing 472/1466: duck fat
# Saved 10 synonyms for duck fat
# Processing 473/1466: duck leg
# Saved 10 synonyms for duck leg
# Processing 474/1466: dungeness crab
# Saved 9 synonyms for dungeness crab
# Processing 475/1466: earl grey
# Saved 10 synonyms for earl grey
# Processing 476/1466: edam
# Saved 10 synonyms for edam
# Processing 477/1466: edamame
# Saved 10 synonyms for edamame
# Processing 478/1466: edible flower
# Saved 10 synonyms for edible flower
# Processing 479/1466: eel
# Saved 9 synonyms for eel
# Processing 480/1466: egg
# Saved 10 synonyms for egg
# Processing 481/1466: egg noodle
# Saved 10 synonyms for egg noodle
# Processing 482/1466: egg roll wrapper
# Saved 10 synonyms for egg roll wrapper
# Processing 483/1466: egg substitute
# Saved 10 synonyms for egg substitute
# Processing 484/1466: egg white
# Saved 10 synonyms for egg white
# Processing 485/1466: egg yolk
# Saved 10 synonyms for egg yolk
# Processing 486/1466: eggplant
# Saved 10 synonyms for eggplant
# Processing 487/1466: elbow macaroni
# Saved 9 synonyms for elbow macaroni
# Processing 488/1466: elderberry
# Saved 10 synonyms for elderberry
# Processing 489/1466: elderflower liqueur
# Saved 10 synonyms for elderflower liqueur
# Processing 490/1466: elk roast
# Saved 9 synonyms for elk roast
# Processing 491/1466: endive
# Saved 10 synonyms for endive
# Processing 492/1466: english cucumber
# Saved 10 synonyms for english cucumber
# Processing 493/1466: english muffin
# Saved 10 synonyms for english muffin
# Processing 494/1466: english mustard
# Saved 10 synonyms for english mustard
# Processing 495/1466: enoki mushroom
# Saved 10 synonyms for enoki mushroom
# Processing 496/1466: epazote
# Saved 10 synonyms for epazote
# Processing 497/1466: escargot
# Saved 10 synonyms for escargot
# Processing 498/1466: escarole
# Saved 10 synonyms for escarole
# Processing 499/1466: espresso
# Saved 10 synonyms for espresso
# Processing 500/1466: evaporated milk
# Saved 10 synonyms for evaporated milk
# Processing 501/1466: everything bagel seasoning
# Saved 9 synonyms for everything bagel seasoning
# Processing 502/1466: farfalle
# Saved 10 synonyms for farfalle
# Processing 503/1466: farfalle tonde
# Saved 9 synonyms for farfalle tonde
# Processing 504/1466: farmer cheese
# Saved 10 synonyms for farmer cheese
# Processing 505/1466: farro
# Saved 10 synonyms for farro
# Processing 506/1466: fat-free sour cream
# Saved 10 synonyms for fat-free sour cream
# Processing 507/1466: fava bean
# Saved 9 synonyms for fava bean
# Processing 508/1466: fennel
# Saved 10 synonyms for fennel
# Processing 509/1466: fennel pollen
# Saved 10 synonyms for fennel pollen
# Processing 510/1466: fennel seed
# Saved 9 synonyms for fennel seed
# Processing 511/1466: fenugreek seed
# Saved 10 synonyms for fenugreek seed
# Processing 512/1466: feta cheese
# Saved 9 synonyms for feta cheese
# Processing 513/1466: fettuccine
# Saved 10 synonyms for fettuccine
# Processing 514/1466: fiddlehead
# Saved 9 synonyms for fiddlehead
# Processing 515/1466: fig
# Saved 10 synonyms for fig
# Processing 516/1466: fig jam
# Saved 10 synonyms for fig jam
# Processing 517/1466: file powder
# Saved 10 synonyms for file powder
# Processing 518/1466: filet mignon
# Saved 10 synonyms for filet mignon
# Processing 519/1466: filo pastry
# Saved 9 synonyms for filo pastry
# Processing 520/1466: fish
# Saved 10 synonyms for fish
# Processing 521/1466: fish fillet
# Saved 10 synonyms for fish fillet
# Processing 522/1466: fish sauce
# Saved 10 synonyms for fish sauce
# Processing 523/1466: fish stock
# Saved 10 synonyms for fish stock
# Processing 524/1466: flank steak
# Saved 10 synonyms for flank steak
# Processing 525/1466: flat iron steak
# Saved 10 synonyms for flat iron steak
# Processing 526/1466: flatbread
# Saved 10 synonyms for flatbread
# Processing 527/1466: flavored yogurt
# Saved 9 synonyms for flavored yogurt
# Processing 528/1466: flax oil
# Saved 10 synonyms for flax oil
# Processing 529/1466: flaxseed
# Saved 10 synonyms for flaxseed
# Processing 530/1466: fleur de sel
# Saved 9 synonyms for fleur de sel
# Processing 531/1466: flounder fillet
# Saved 10 synonyms for flounder fillet
# Processing 532/1466: flour
# Saved 10 synonyms for flour
# Processing 533/1466: focaccia
# Saved 9 synonyms for focaccia
# Processing 534/1466: foie gras
# Saved 10 synonyms for foie gras
# Processing 535/1466: fontina
# Saved 9 synonyms for fontina
# Processing 536/1466: food color
# Saved 10 synonyms for food color
# Processing 537/1466: fregula
# Saved 9 synonyms for fregula
# Processing 538/1466: french bread
# Saved 9 synonyms for french bread
# Processing 539/1466: french fry
# Saved 10 synonyms for french fry
# Processing 540/1466: french lentil
# Saved 10 synonyms for french lentil
# Processing 541/1466: french mustard
# Saved 9 synonyms for french mustard
# Processing 542/1466: fresh basil
# Saved 10 synonyms for fresh basil
# Processing 543/1466: fresh nutmeg
# Saved 9 synonyms for fresh nutmeg
# Processing 544/1466: fresh yeast
# Saved 10 synonyms for fresh yeast
# Processing 545/1466: fresno pepper
# Saved 9 synonyms for fresno pepper
# Processing 546/1466: fried onion
# Saved 10 synonyms for fried onion
# Processing 547/1466: fried rice
# Saved 10 synonyms for fried rice
# Processing 548/1466: frozen corn
# Saved 10 synonyms for frozen corn
# Processing 549/1466: frozen pizza
# Saved 10 synonyms for frozen pizza
# Processing 550/1466: fruit
# Saved 10 synonyms for fruit
# Processing 551/1466: fruit cocktail
# Saved 10 synonyms for fruit cocktail
# Processing 552/1466: fruit juice
# Saved 10 synonyms for fruit juice
# Processing 553/1466: fruit pectin
# Saved 10 synonyms for fruit pectin
# Processing 554/1466: fudge
# Saved 10 synonyms for fudge
# Processing 555/1466: fudge sauce
# Saved 10 synonyms for fudge sauce
# Processing 556/1466: galangal
# Saved 9 synonyms for galangal
# Processing 557/1466: garam masala
# Saved 10 synonyms for garam masala
# Processing 558/1466: garden cress
# Saved 9 synonyms for garden cress
# Processing 559/1466: garlic
# Saved 10 synonyms for garlic
# Processing 560/1466: garlic herb cheese
# Saved 10 synonyms for garlic herb cheese
# Processing 561/1466: garlic oil
# Saved 10 synonyms for garlic oil
# Processing 562/1466: garlic powder
# Saved 10 synonyms for garlic powder
# Processing 563/1466: garlic salt
# Saved 10 synonyms for garlic salt
# Processing 564/1466: garlic scapes
# Saved 10 synonyms for garlic scapes
# Processing 565/1466: gelatin
# Saved 10 synonyms for gelatin
# Processing 566/1466: gemelli
# Saved 10 synonyms for gemelli
# Processing 567/1466: gigante bean
# Saved 10 synonyms for gigante bean
# Processing 568/1466: gin
# Saved 10 synonyms for gin
# Processing 569/1466: ginger
# Saved 10 synonyms for ginger
# Processing 570/1466: ginger ale
# Saved 10 synonyms for ginger ale
# Processing 571/1466: ginger juice
# Saved 10 synonyms for ginger juice
# Processing 572/1466: ginger paste
# Saved 10 synonyms for ginger paste
# Processing 573/1466: gingersnap crumb
# Saved 9 synonyms for gingersnap crumb
# Processing 574/1466: gnocchi
# Saved 10 synonyms for gnocchi
# Processing 575/1466: goat cheese
# Saved 10 synonyms for goat cheese
# Processing 576/1466: goat milk
# Saved 9 synonyms for goat milk
# Processing 577/1466: gochugaru
# Saved 10 synonyms for gochugaru
# Processing 578/1466: gochujang
# Saved 10 synonyms for gochujang
# Processing 579/1466: goji berry
# Saved 10 synonyms for goji berry
# Processing 580/1466: golden beet
# Saved 10 synonyms for golden beet
# Processing 581/1466: golden syrup
# Saved 10 synonyms for golden syrup
# Processing 582/1466: goldfish crackers
# Saved 9 synonyms for goldfish crackers
# Processing 583/1466: gomashio
# Saved 9 synonyms for gomashio
# Processing 584/1466: goose fat
# Saved 10 synonyms for goose fat
# Processing 585/1466: gooseberry
# Saved 9 synonyms for gooseberry
# Processing 586/1466: gorgonzola
# Saved 10 synonyms for gorgonzola
# Processing 587/1466: gouda
# Saved 10 synonyms for gouda
# Processing 588/1466: graham flour
# Saved 9 synonyms for graham flour
# Processing 589/1466: grain blend
# Saved 10 synonyms for grain blend
# Processing 590/1466: grana padano
# Saved 10 synonyms for grana padano
# Processing 591/1466: grand marnier
# Saved 9 synonyms for grand marnier
# Processing 592/1466: granola
# Saved 10 synonyms for granola
# Processing 593/1466: granulated garlic
# Saved 10 synonyms for granulated garlic
# Processing 594/1466: granulated onion
# Saved 10 synonyms for granulated onion
# Processing 595/1466: grape
# Saved 10 synonyms for grape
# Processing 596/1466: grape juice
# Saved 10 synonyms for grape juice
# Processing 597/1466: grape leaf
# Saved 10 synonyms for grape leaf
# Processing 598/1466: grape seed oil
# Saved 10 synonyms for grape seed oil
# Processing 599/1466: grapefruit
# Saved 9 synonyms for grapefruit
# Processing 600/1466: grapefruit juice
# Saved 10 synonyms for grapefruit juice
# Processing 601/1466: grapefruit zest
# Saved 10 synonyms for grapefruit zest
# Processing 602/1466: grappa
# Saved 10 synonyms for grappa
# Processing 603/1466: gravlax
# Saved 9 synonyms for gravlax
# Processing 604/1466: great northern bean
# Saved 9 synonyms for great northern bean
# Processing 605/1466: greek olive
# Saved 10 synonyms for greek olive
# Processing 606/1466: greek yogurt
# Saved 9 synonyms for greek yogurt
# Processing 607/1466: green bean
# Saved 9 synonyms for green bean
# Processing 608/1466: green chile
# Saved 10 synonyms for green chile
# Processing 609/1466: green curry paste
# Saved 10 synonyms for green curry paste
# Processing 610/1466: green enchilada sauce
# Saved 10 synonyms for green enchilada sauce
# Processing 611/1466: green grape
# Saved 10 synonyms for green grape
# Processing 612/1466: green olive
# Saved 9 synonyms for green olive
# Processing 613/1466: green onion
# Saved 10 synonyms for green onion
# Processing 614/1466: green papaya
# Saved 10 synonyms for green papaya
# Processing 615/1466: green pea
# Saved 10 synonyms for green pea
# Processing 616/1466: green tomato
# Saved 9 synonyms for green tomato
# Processing 617/1466: grenadine
# Saved 9 synonyms for grenadine
# Processing 618/1466: grilled chicken
# Saved 10 synonyms for grilled chicken
# Processing 619/1466: grilling cheese
# Saved 10 synonyms for grilling cheese
# Processing 620/1466: grit
# Saved 10 synonyms for grit
# Processing 621/1466: ground allspice
# Saved 10 synonyms for ground allspice
# Processing 622/1466: ground beef
# Saved 10 synonyms for ground beef
# Processing 623/1466: ground chicken
# Saved 10 synonyms for ground chicken
# Processing 624/1466: ground clove
# Saved 10 synonyms for ground clove
# Processing 625/1466: ground fennel
# Saved 10 synonyms for ground fennel
# Processing 626/1466: ground fenugreek
# Saved 10 synonyms for ground fenugreek
# Processing 627/1466: ground flaxseed
# Saved 10 synonyms for ground flaxseed
# Processing 628/1466: ground ginger
# Saved 10 synonyms for ground ginger
# Processing 629/1466: ground lamb
# Saved 10 synonyms for ground lamb
# Processing 630/1466: ground mace
# Saved 10 synonyms for ground mace
# Processing 631/1466: ground pork
# Saved 10 synonyms for ground pork
# Processing 632/1466: ground pork sausage
# Saved 10 synonyms for ground pork sausage
# Processing 633/1466: ground savory
# Saved 10 synonyms for ground savory
# Processing 634/1466: ground thyme
# Saved 10 synonyms for ground thyme
# Processing 635/1466: ground turkey
# Saved 10 synonyms for ground turkey
# Processing 636/1466: ground veal
# Saved 10 synonyms for ground veal
# Processing 637/1466: grouper
# Saved 10 synonyms for grouper
# Processing 638/1466: gruyere
# Saved 10 synonyms for gruyere
# Processing 639/1466: guacamole
# Saved 10 synonyms for guacamole
# Processing 640/1466: guajillo pepper
# Saved 10 synonyms for guajillo pepper
# Processing 641/1466: guanciale
# Saved 9 synonyms for guanciale
# Processing 642/1466: guava
# Saved 10 synonyms for guava
# Processing 643/1466: guinea fowl
# Saved 10 synonyms for guinea fowl
# Processing 644/1466: habanero chili
# Saved 10 synonyms for habanero chili
# Processing 645/1466: haddock
# Saved 9 synonyms for haddock
# Processing 646/1466: hake
# Saved 10 synonyms for hake
# Processing 647/1466: half and half
# Saved 10 synonyms for half and half
# Processing 648/1466: halibut fillet
# Saved 9 synonyms for halibut fillet
# Processing 649/1466: halloumi
# Saved 9 synonyms for halloumi
# Processing 650/1466: ham
# Saved 10 synonyms for ham
# Processing 651/1466: ham bone
# Saved 10 synonyms for ham bone
# Processing 652/1466: ham slice
# Saved 10 synonyms for ham slice
# Processing 653/1466: hamburger bun
# Saved 10 synonyms for hamburger bun
# Processing 654/1466: hamburger helper
# Saved 10 synonyms for hamburger helper
# Processing 655/1466: haricot vert
# Saved 10 synonyms for haricot vert
# Processing 656/1466: harissa
# Saved 10 synonyms for harissa
# Processing 657/1466: hash brown
# Saved 10 synonyms for hash brown
# Processing 658/1466: havarti
# Saved 10 synonyms for havarti
# Processing 659/1466: hazelnut
# Saved 10 synonyms for hazelnut
# Processing 660/1466: hazelnut flour
# Saved 10 synonyms for hazelnut flour
# Processing 661/1466: hazelnut oil
# Saved 10 synonyms for hazelnut oil
# Processing 662/1466: hearts of palm
# Saved 10 synonyms for hearts of palm
# Processing 663/1466: hemp milk
# Saved 10 synonyms for hemp milk
# Processing 664/1466: hemp oil
# Saved 10 synonyms for hemp oil
# Processing 665/1466: hemp seed
# Saved 10 synonyms for hemp seed
# Processing 666/1466: herb
# Saved 10 synonyms for herb
# Processing 667/1466: herbes de provence
# Saved 10 synonyms for herbes de provence
# Processing 668/1466: herring
# Saved 10 synonyms for herring
# Processing 669/1466: herring fillet
# Saved 9 synonyms for herring fillet
# Processing 670/1466: hoisin sauce
# Saved 9 synonyms for hoisin sauce
# Processing 671/1466: hollandaise sauce
# Saved 10 synonyms for hollandaise sauce
# Processing 672/1466: hominy
# Saved 9 synonyms for hominy
# Processing 673/1466: honey
# Saved 10 synonyms for honey
# Processing 674/1466: honey mustard
# Saved 10 synonyms for honey mustard
# Processing 675/1466: horseradish
# Saved 9 synonyms for horseradish
# Processing 676/1466: horseradish sauce
# Saved 9 synonyms for horseradish sauce
# Processing 677/1466: hot cherry pepper
# Saved 10 synonyms for hot cherry pepper
# Processing 678/1466: hot dog
# Saved 10 synonyms for hot dog
# Processing 679/1466: hot fudge
# Saved 10 synonyms for hot fudge
# Processing 680/1466: hot sauce
# Saved 10 synonyms for hot sauce
# Processing 681/1466: hp sauce
# Saved 10 synonyms for hp sauce
# Processing 682/1466: hummus
# Saved 9 synonyms for hummus
# Processing 683/1466: ice
# Saved 10 synonyms for ice
# Processing 684/1466: ice cream cone
# Saved 10 synonyms for ice cream cone
# Processing 685/1466: ice cream sandwich
# Saved 9 synonyms for ice cream sandwich
# Processing 686/1466: iceburg lettuce
# Saved 10 synonyms for iceburg lettuce
# Processing 687/1466: icing
# Saved 10 synonyms for icing
# Processing 688/1466: icing gel
# Saved 10 synonyms for icing gel
# Processing 689/1466: imitation crab
# Saved 10 synonyms for imitation crab
# Processing 690/1466: instant coffee
# Saved 10 synonyms for instant coffee
# Processing 691/1466: instant grit
# Saved 10 synonyms for instant grit
# Processing 692/1466: ipa
# Saved 10 synonyms for ipa
# Processing 693/1466: israeli couscous
# Saved 10 synonyms for israeli couscous
# Processing 694/1466: italian sausage
# Saved 10 synonyms for italian sausage
# Processing 695/1466: italian seasoning
# Saved 10 synonyms for italian seasoning
# Processing 696/1466: italian toast cracker
# Saved 10 synonyms for italian toast cracker
# Processing 697/1466: jalapeno jelly
# Saved 10 synonyms for jalapeno jelly
# Processing 698/1466: jalapeno pepper
# Saved 10 synonyms for jalapeno pepper
# Processing 699/1466: jam
# Saved 10 synonyms for jam
# Processing 700/1466: jamon
# Saved 10 synonyms for jamon
# Processing 701/1466: jarlsberg cheese
# Saved 9 synonyms for jarlsberg cheese
# Processing 702/1466: jasmine rice
# Saved 10 synonyms for jasmine rice
# Processing 703/1466: jerk seasoning
# Saved 10 synonyms for jerk seasoning
# Processing 704/1466: jicama
# Saved 9 synonyms for jicama
# Processing 705/1466: juice
# Saved 10 synonyms for juice
# Processing 706/1466: juniper berry
# Saved 10 synonyms for juniper berry
# Processing 707/1466: kabocha squash
# Saved 9 synonyms for kabocha squash
# Processing 708/1466: kaffir lime leaf
# Saved 9 synonyms for kaffir lime leaf
# Processing 709/1466: kalamata olive
# Saved 8 synonyms for kalamata olive
# Processing 710/1466: kale
# Saved 10 synonyms for kale
# Processing 711/1466: kamut
# Saved 10 synonyms for kamut
# Processing 712/1466: kecap manis
# Saved 9 synonyms for kecap manis
# Processing 713/1466: kelp
# Saved 9 synonyms for kelp
# Processing 714/1466: ketchup
# Saved 9 synonyms for ketchup
# Processing 715/1466: kidney
# Saved 10 synonyms for kidney
# Processing 716/1466: kidney bean
# Saved 9 synonyms for kidney bean
# Processing 717/1466: kielbasa
# ...
# Processing 1232/1466: sourdough starter
# Saved 10 synonyms for sourdough starter
# Processing 1233/1466: soy buttery spread
# Saved 10 synonyms for soy buttery spread
# Processing 1234/1466: soy cheese
# Saved 10 synonyms for soy cheese
# Processing 1235/1466: soy protein powder
# Saved 10 synonyms for soy protein powder
# Processing 1236/1466: soy sauce
# Saved 10 synonyms for soy sauce
# Processing 1237/1466: soybean
# Saved 10 synonyms for soybean
# Processing 1238/1466: soybean oil
# Saved 10 synonyms for soybean oil
# Processing 1239/1466: soymilk
# Saved 10 synonyms for soymilk
# Processing 1240/1466: spaghetti
# Saved 10 synonyms for spaghetti
# Processing 1241/1466: spaghetti squash
# Saved 9 synonyms for spaghetti squash
# Processing 1242/1466: spaghettini
# Saved 10 synonyms for spaghettini
# Processing 1243/1466: sparkling water
# Saved 10 synonyms for sparkling water
# Processing 1244/1466: sparkling wine
# Saved 10 synonyms for sparkling wine
# Processing 1245/1466: speck
# Saved 10 synonyms for speck
# Processing 1246/1466: spelt
# Saved 10 synonyms for spelt
# Processing 1247/1466: spelt flour
# Saved 10 synonyms for spelt flour
# Processing 1248/1466: spicy brown mustard
# Saved 10 synonyms for spicy brown mustard
# Processing 1249/1466: spinach
# Saved 10 synonyms for spinach
# Processing 1250/1466: spinach tortellini
# Saved 9 synonyms for spinach tortellini
# Processing 1251/1466: sprat
# Saved 9 synonyms for sprat
# Processing 1252/1466: spring mix
# Saved 10 synonyms for spring mix
# Processing 1253/1466: spring roll wrapper
# Saved 10 synonyms for spring roll wrapper
# Processing 1254/1466: sprinkles
# Saved 10 synonyms for sprinkles
# Processing 1255/1466: sprout
# Saved 10 synonyms for sprout
# Processing 1256/1466: squash
# Saved 10 synonyms for squash
# Processing 1257/1466: squash blossom
# Saved 10 synonyms for squash blossom
# Processing 1258/1466: squid
# Saved 10 synonyms for squid
# Processing 1259/1466: squid ink pasta
# Saved 10 synonyms for squid ink pasta
# Processing 1260/1466: sriracha
# Saved 9 synonyms for sriracha
# Processing 1261/1466: star anise
# Saved 10 synonyms for star anise
# Processing 1262/1466: starfruit
# Saved 10 synonyms for starfruit
# Processing 1263/1466: steak
# Saved 10 synonyms for steak
# Processing 1264/1466: steak sauce
# Saved 10 synonyms for steak sauce
# Processing 1265/1466: steel cut oat
# Saved 10 synonyms for steel cut oat
# Processing 1266/1466: stevia
# Saved 10 synonyms for stevia
# Processing 1267/1466: stewed tomato
# Saved 10 synonyms for stewed tomato
# Processing 1268/1466: sticky rice
# Saved 10 synonyms for sticky rice
# Processing 1269/1466: stilton
# Saved 9 synonyms for stilton
# Processing 1270/1466: stock
# Saved 10 synonyms for stock
# Processing 1271/1466: stout
# Saved 10 synonyms for stout
# Processing 1272/1466: straw mushroom
# Saved 10 synonyms for straw mushroom
# Processing 1273/1466: strawberry
# Saved 10 synonyms for strawberry
# Processing 1274/1466: strawberry pie filling
# Saved 10 synonyms for strawberry pie filling
# Processing 1275/1466: strip loin
# Saved 9 synonyms for strip loin
# Processing 1276/1466: stuffed olive
# Saved 10 synonyms for stuffed olive
# Processing 1277/1466: stuffing
# Saved 10 synonyms for stuffing
# Processing 1278/1466: stuffing mix
# Saved 10 synonyms for stuffing mix
# Processing 1279/1466: sub roll
# Saved 10 synonyms for sub roll
# Processing 1280/1466: sucralose
# Saved 10 synonyms for sucralose
# Processing 1281/1466: suet
# Saved 10 synonyms for suet
# Processing 1282/1466: sugar
# Saved 10 synonyms for sugar
# Processing 1283/1466: sugar pea
# Saved 9 synonyms for sugar pea
# Processing 1284/1466: sumac
# Saved 9 synonyms for sumac
# Processing 1285/1466: summer savory
# Saved 9 synonyms for summer savory
# Processing 1286/1466: summer squash
# Saved 10 synonyms for summer squash
# Processing 1287/1466: sun dried tomato
# Saved 10 synonyms for sun dried tomato
# Processing 1288/1466: sunchoke
# Saved 10 synonyms for sunchoke
# Processing 1289/1466: sunflower oil
# Saved 10 synonyms for sunflower oil
# Processing 1290/1466: sunflower seed
# Saved 9 synonyms for sunflower seed
# Processing 1291/1466: sunflower shoot
# Saved 10 synonyms for sunflower shoot
# Processing 1292/1466: superfine sugar
# Saved 9 synonyms for superfine sugar
# Processing 1293/1466: sweet chili sauce
# Saved 9 synonyms for sweet chili sauce
# Processing 1294/1466: sweet onion
# Saved 10 synonyms for sweet onion
# Processing 1295/1466: sweet pickle
# Saved 10 synonyms for sweet pickle
# Processing 1296/1466: sweet pickle relish
# Saved 10 synonyms for sweet pickle relish
# Processing 1297/1466: sweet potato
# Saved 10 synonyms for sweet potato
# Processing 1298/1466: sweetened condensed milk
# Saved 10 synonyms for sweetened condensed milk
# Processing 1299/1466: swiss
# Saved 10 synonyms for swiss
# Processing 1300/1466: swiss chard
# Saved 10 synonyms for swiss chard
# Processing 1301/1466: swiss cheese
# Saved 10 synonyms for swiss cheese
# Processing 1302/1466: swordfish
# Saved 9 synonyms for swordfish
# Processing 1303/1466: syrup
# Saved 10 synonyms for syrup
# Processing 1304/1466: tabasco sauce
# Saved 10 synonyms for tabasco sauce
# Processing 1305/1466: table salt
# Saved 10 synonyms for table salt
# Processing 1306/1466: table syrup
# Saved 10 synonyms for table syrup
# Processing 1307/1466: taco seasoning
# Saved 10 synonyms for taco seasoning
# Processing 1308/1466: taco shell
# Saved 10 synonyms for taco shell
# Processing 1309/1466: tagliatelle
# Saved 10 synonyms for tagliatelle
# Processing 1310/1466: tahini
# Saved 10 synonyms for tahini
# Processing 1311/1466: taleggio cheese
# Saved 9 synonyms for taleggio cheese
# Processing 1312/1466: tamari
# Saved 10 synonyms for tamari
# Processing 1313/1466: tamarind
# Saved 10 synonyms for tamarind
# Processing 1314/1466: tamarind juice
# Saved 10 synonyms for tamarind juice
# Processing 1315/1466: tamarind pulp
# Saved 10 synonyms for tamarind pulp
# Processing 1316/1466: tangerine
# Saved 10 synonyms for tangerine
# Processing 1317/1466: tapioca pearl
# Saved 10 synonyms for tapioca pearl
# Processing 1318/1466: tapioca starch
# Saved 10 synonyms for tapioca starch
# Processing 1319/1466: tarragon
# Saved 9 synonyms for tarragon
# Processing 1320/1466: tarragon vinegar
# Saved 9 synonyms for tarragon vinegar
# Processing 1321/1466: tart cherry
# Saved 10 synonyms for tart cherry
# Processing 1322/1466: tartar sauce
# Saved 10 synonyms for tartar sauce
# Processing 1323/1466: tea
# Saved 10 synonyms for tea
# Processing 1324/1466: tempeh
# Saved 10 synonyms for tempeh
# Processing 1325/1466: tempura batter mix
# Saved 10 synonyms for tempura batter mix
# Processing 1326/1466: teriyaki sauce
# Saved 10 synonyms for teriyaki sauce
# Processing 1327/1466: thai basil
# Saved 10 synonyms for thai basil
# Processing 1328/1466: thai chili
# Saved 10 synonyms for thai chili
# Processing 1329/1466: thin baguette
# Saved 10 synonyms for thin baguette
# Processing 1330/1466: thousand island dressing
# Saved 9 synonyms for thousand island dressing
# Processing 1331/1466: thyme
# Saved 10 synonyms for thyme
# Processing 1332/1466: tiger nut
# Saved 10 synonyms for tiger nut
# Processing 1333/1466: tilapia
# Saved 9 synonyms for tilapia
# Processing 1334/1466: tip roast
# Saved 10 synonyms for tip roast
# Processing 1335/1466: tofu
# Saved 9 synonyms for tofu
# Processing 1336/1466: tofu skin
# Saved 10 synonyms for tofu skin
# Processing 1337/1466: tomatillos
# Saved 9 synonyms for tomatillos
# Processing 1338/1466: tomato
# Saved 9 synonyms for tomato
# Processing 1339/1466: tomato concentrate
# Saved 10 synonyms for tomato concentrate
# Processing 1340/1466: tomato juice
# Saved 9 synonyms for tomato juice
# Processing 1341/1466: tomato paste
# Saved 10 synonyms for tomato paste
# Processing 1342/1466: tomato pesto
# Saved 10 synonyms for tomato pesto
# Processing 1343/1466: tomato puree
# Saved 10 synonyms for tomato puree
# Processing 1344/1466: tomato sauce
# Saved 10 synonyms for tomato sauce
# Processing 1345/1466: tomato soup
# Saved 10 synonyms for tomato soup
# Processing 1346/1466: tortilla
# Saved 10 synonyms for tortilla
# Processing 1347/1466: tortilla chip
# Saved 10 synonyms for tortilla chip
# Processing 1348/1466: tostada
# Saved 10 synonyms for tostada
# Processing 1349/1466: tri tip steak
# Saved 10 synonyms for tri tip steak
# Processing 1350/1466: triple sec
# Saved 10 synonyms for triple sec
# Processing 1351/1466: triticale
# Saved 10 synonyms for triticale
# Processing 1352/1466: trout fillet
# Saved 9 synonyms for trout fillet
# Processing 1353/1466: truffle oil
# Saved 9 synonyms for truffle oil
# Processing 1354/1466: tubetti
# Saved 10 synonyms for tubetti
# Processing 1355/1466: tuna
# Saved 10 synonyms for tuna
# Processing 1356/1466: turbot
# Saved 10 synonyms for turbot
# Processing 1357/1466: turkey
# Saved 10 synonyms for turkey
# Processing 1358/1466: turkey bacon
# Saved 9 synonyms for turkey bacon
# Processing 1359/1466: turkey breast
# Saved 10 synonyms for turkey breast
# Processing 1360/1466: turkey breast cutlets
# Saved 10 synonyms for turkey breast cutlets
# Processing 1361/1466: turkey broth
# Saved 10 synonyms for turkey broth
# Processing 1362/1466: turkey burger
# Saved 9 synonyms for turkey burger
# Processing 1363/1466: turkey drumstick
# Saved 10 synonyms for turkey drumstick
# Processing 1364/1466: turkey giblet
# Saved 10 synonyms for turkey giblet
# Processing 1365/1466: turkey kielbasa
# Saved 9 synonyms for turkey kielbasa
# Processing 1366/1466: turkey neck
# Saved 10 synonyms for turkey neck
# Processing 1367/1466: turkey sausage
# Saved 10 synonyms for turkey sausage
# Processing 1368/1466: turkey stock
# Saved 9 synonyms for turkey stock
# Processing 1369/1466: turkey thigh
# Saved 9 synonyms for turkey thigh
# Processing 1370/1466: turkey wing
# Saved 10 synonyms for turkey wing
# Processing 1371/1466: turmeric
# Saved 10 synonyms for turmeric
# Processing 1372/1466: turnip
# Saved 10 synonyms for turnip
# Processing 1373/1466: turnip green
# Saved 10 synonyms for turnip green
# Processing 1374/1466: tzatziki
# Saved 10 synonyms for tzatziki
# Processing 1375/1466: udon noodle
# Saved 9 synonyms for udon noodle
# Processing 1376/1466: unsalted butter
# Saved 9 synonyms for unsalted butter
# Processing 1377/1466: vanilla
# Saved 10 synonyms for vanilla
# Processing 1378/1466: vanilla bean
# Saved 10 synonyms for vanilla bean
# Processing 1379/1466: vanilla extract
# Saved 10 synonyms for vanilla extract
# Processing 1380/1466: vanilla ice cream
# Saved 10 synonyms for vanilla ice cream
# Processing 1381/1466: vanilla paste
# Saved 10 synonyms for vanilla paste
# Processing 1382/1466: vanilla protein powder
# Saved 10 synonyms for vanilla protein powder
# Processing 1383/1466: vanilla yogurt
# Saved 10 synonyms for vanilla yogurt
# Processing 1384/1466: veal
# Saved 10 synonyms for veal
# Processing 1385/1466: veal bone
# Saved 10 synonyms for veal bone
# Processing 1386/1466: veal chop
# Saved 9 synonyms for veal chop
# Processing 1387/1466: veal shank
# Saved 10 synonyms for veal shank
# Processing 1388/1466: veal stock
# Saved 10 synonyms for veal stock
# Processing 1389/1466: vegan butter
# Saved 10 synonyms for vegan butter
# Processing 1390/1466: vegan mayo
# Saved 9 synonyms for vegan mayo
# Processing 1391/1466: vegetable
# Saved 10 synonyms for vegetable
# Processing 1392/1466: vegetable juice
# Saved 10 synonyms for vegetable juice
# Processing 1393/1466: vegetable oil
# Saved 10 synonyms for vegetable oil
# Processing 1394/1466: vegetable oil cooking spray
# Saved 10 synonyms for vegetable oil cooking spray
# Processing 1395/1466: vegetable stock
# Saved 10 synonyms for vegetable stock
# Processing 1396/1466: veggie bacon
# Saved 10 synonyms for veggie bacon
# Processing 1397/1466: veggie dog
# Saved 9 synonyms for veggie dog
# Processing 1398/1466: venison
# Saved 10 synonyms for venison
# Processing 1399/1466: venison loin
# Saved 10 synonyms for venison loin
# Processing 1400/1466: venison shoulder
# Saved 10 synonyms for venison shoulder
# Processing 1401/1466: verjus
# Saved 10 synonyms for verjus
# Processing 1402/1466: vinaigrette
# Saved 9 synonyms for vinaigrette
# Processing 1403/1466: vodka
# Saved 9 synonyms for vodka
# Processing 1404/1466: wakame
# Saved 10 synonyms for wakame
# Processing 1405/1466: walnut
# Saved 10 synonyms for walnut
# Processing 1406/1466: walnut oil
# Saved 9 synonyms for walnut oil
# Processing 1407/1466: wasabi
# Saved 10 synonyms for wasabi
# Processing 1408/1466: wasabi pea
# Saved 10 synonyms for wasabi pea
# Processing 1409/1466: water
# Saved 10 synonyms for water
# Processing 1410/1466: watercress
# Saved 10 synonyms for watercress
# Processing 1411/1466: watermelon
# Saved 10 synonyms for watermelon
# Processing 1412/1466: watermelon radish
# Saved 9 synonyms for watermelon radish
# Processing 1413/1466: wax bean
# Saved 9 synonyms for wax bean
# Processing 1414/1466: wheat berry
# Saved 10 synonyms for wheat berry
# Processing 1415/1466: wheat chex
# Saved 10 synonyms for wheat chex
# Processing 1416/1466: wheat cracker
# Saved 9 synonyms for wheat cracker
# Processing 1417/1466: wheat flour
# Saved 10 synonyms for wheat flour
# Processing 1418/1466: wheat germ
# Saved 9 synonyms for wheat germ
# Processing 1419/1466: wheat pastry flour
# Saved 10 synonyms for wheat pastry flour
# Processing 1420/1466: wheat tortilla
# Saved 10 synonyms for wheat tortilla
# Processing 1421/1466: wheatberry
# Saved 10 synonyms for wheatberry
# Processing 1422/1466: whipped butter
# Saved 10 synonyms for whipped butter
# Processing 1423/1466: whipped cream
# Saved 10 synonyms for whipped cream
# Processing 1424/1466: whipped topping
# Saved 10 synonyms for whipped topping
# Processing 1425/1466: whipping cream
# Saved 10 synonyms for whipping cream
# Processing 1426/1466: whiskey
# Saved 10 synonyms for whiskey
# Processing 1427/1466: white asparagus
# Saved 10 synonyms for white asparagus
# Processing 1428/1466: white bean
# Saved 9 synonyms for white bean
# Processing 1429/1466: white bread
# Saved 10 synonyms for white bread
# Processing 1430/1466: white corn
# Saved 10 synonyms for white corn
# Processing 1431/1466: white cornmeal
# Saved 10 synonyms for white cornmeal
# Processing 1432/1466: white pepper
# Saved 10 synonyms for white pepper
# Processing 1433/1466: white rice
# Saved 10 synonyms for white rice
# Processing 1434/1466: white vinegar
# Saved 10 synonyms for white vinegar
# Processing 1435/1466: white wine
# Saved 10 synonyms for white wine
# Processing 1436/1466: whitebait
# Saved 9 synonyms for whitebait
# Processing 1437/1466: whiting
# Saved 10 synonyms for whiting
# Processing 1438/1466: whole chicken
# Saved 10 synonyms for whole chicken
# Processing 1439/1466: whole coconut
# Saved 10 synonyms for whole coconut
# Processing 1440/1466: whole grain mustard
# Saved 10 synonyms for whole grain mustard
# Processing 1441/1466: whole turkey
# Saved 10 synonyms for whole turkey
# Processing 1442/1466: whole wheat bread
# Saved 10 synonyms for whole wheat bread
# Processing 1443/1466: whole wheat breadcrumb
# Saved 9 synonyms for whole wheat breadcrumb
# Processing 1444/1466: whole wheat flour
# Saved 9 synonyms for whole wheat flour
# Processing 1445/1466: whole wheat fusilli
# Saved 9 synonyms for whole wheat fusilli
# Processing 1446/1466: whole wheat penne
# Saved 10 synonyms for whole wheat penne
# Processing 1447/1466: wild leek
# Saved 10 synonyms for wild leek
# Processing 1448/1466: wild rice
# Saved 9 synonyms for wild rice
# Processing 1449/1466: wine
# Saved 10 synonyms for wine
# Processing 1450/1466: wine vinegar
# Saved 10 synonyms for wine vinegar
# Processing 1451/1466: wondra flour
# Saved 9 synonyms for wondra flour
# Processing 1452/1466: wonton wrappers
# Saved 10 synonyms for wonton wrappers
# Processing 1453/1466: worcestershire sauce
# Saved 9 synonyms for worcestershire sauce
# Processing 1454/1466: wrap
# Saved 10 synonyms for wrap
# Processing 1455/1466: xanthan gum
# Saved 7 synonyms for xanthan gum
# Processing 1456/1466: yam
# Saved 10 synonyms for yam
# Processing 1457/1466: yeast
# Saved 10 synonyms for yeast
# Processing 1458/1466: yellow pepper
# Saved 10 synonyms for yellow pepper
# Processing 1459/1466: yellow squash
# Saved 10 synonyms for yellow squash
# Processing 1460/1466: yellowfin tuna
# Saved 9 synonyms for yellowfin tuna
# Processing 1461/1466: yogurt
# Saved 10 synonyms for yogurt
# Processing 1462/1466: yuzu
# Saved 9 synonyms for yuzu
# Processing 1463/1466: yuzu juice
# Saved 10 synonyms for yuzu juice
# Processing 1464/1466: zaatar
# Saved 9 synonyms for zaatar
# Processing 1465/1466: zinfandel
# Saved 9 synonyms for zinfandel
# Processing 1466/1466: zucchini
# Saved 9 synonyms for zucchini
